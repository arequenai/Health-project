# %%
### Attempting to get the formula for TSS from garmin data ###

# Import necessary modules and functions
import os, datetime
import pandas as pd
from ETL.ETL_garmin_api import init_garmin, get_garmin_data

garmin_file = 'Data/Cleaned/Garmin_daily.csv'
email_g = os.getenv("USERNAME_G")
password_g = os.getenv("PASSWORD_G")
api = init_garmin(email_g, password_g)

# Get TP data
df_t = pd.read_csv('Data/Cleaned/TSS metrics.csv')
df_t['date'] = pd.to_datetime(df_t['date']).dt.date
df_t = df_t[['date', 'TSS']]

# Get Garmin data
start_date = df_t['date'].min()
data_list = api.get_activities_by_date(start_date, datetime.date.today(), activitytype='running')
# Convert list of dictionaries to DataFrame
df_g = pd.DataFrame(data_list)

# %%
# Show all columns
pd.set_option('display.max_columns', None)
df_g.head()
# Out:
#     activityId        activityName description       startTimeLocal  \
# 0  15553217776      Madrid Carrera        None  2024-05-24 12:02:32
# 1  15517498291  Vila-Seca - 10x300        None  2024-05-22 06:59:13
# 2  15464994914      Madrid Carrera        None  2024-05-19 07:05:06
# 3  15433085610     Madrid - 12x300        None  2024-05-17 07:01:40
# 4  15403874461      Madrid Carrera        None  2024-05-15 11:30:44
#
#           startTimeGMT                                       activityType  \
# 0  2024-05-24 10:02:32  {'typeId': 1, 'typeKey': 'running', 'parentTyp...
# 1  2024-05-22 04:59:13  {'typeId': 1, 'typeKey': 'running', 'parentTyp...
# 2  2024-05-19 05:05:06  {'typeId': 1, 'typeKey': 'running', 'parentTyp...
# 3  2024-05-17 05:01:40  {'typeId': 1, 'typeKey': 'running', 'parentTyp...
# 4  2024-05-15 09:30:44  {'typeId': 1, 'typeKey': 'running', 'parentTyp...
#
#                                            eventType comments parentId  \
# 0  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...     None     None
# 1  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...     None     None
# 2  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...     None     None
# 3  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...     None     None
# 4  {'typeId': 9, 'typeKey': 'uncategorized', 'sor...     None     None
#
#        distance     duration  elapsedDuration  movingDuration  elevationGain  \
# 0   7208.600098  2243.000000      2243.000000     2200.093994          53.11
# 1  12047.719727  3832.500000      3832.500000     3821.663010          43.47
# 2  18280.839844  5691.665039      5691.665039     5687.010010         179.52
# 3   9279.959961  3083.914062      3083.914062     3079.643013          41.89
# 4  17284.039062  5347.430176      5347.430176     5316.212036         164.94
#
#    elevationLoss  averageSpeed  maxSpeed  startLatitude  startLongitude  \
# 0          51.10         3.214     3.928      40.458040       -3.695123
# 1          46.50         3.144     5.309      41.107647        1.148201
# 2         187.25         3.212     4.161      40.458003       -3.697319
# 3          39.51         3.009     4.665      40.457845       -3.698355
# 4         184.11         3.232     3.863      40.457938       -3.696035
#
#    hasPolyline  hasImages   ownerId                      ownerDisplayName  \
# 0         True      False  76018113  c13a59ed-71ec-4d12-a7ac-0182d6d2ed57
# 1         True      False  76018113  c13a59ed-71ec-4d12-a7ac-0182d6d2ed57
# 2         True      False  76018113  c13a59ed-71ec-4d12-a7ac-0182d6d2ed57
# 3         True      False  76018113  c13a59ed-71ec-4d12-a7ac-0182d6d2ed57
# 4         True      False  76018113  c13a59ed-71ec-4d12-a7ac-0182d6d2ed57
#
#      ownerFullName                          ownerProfileImageUrlSmall  \
# 0  Alberto Requena  https://s3.amazonaws.com/garmin-connect-prod/p...
# 1  Alberto Requena  https://s3.amazonaws.com/garmin-connect-prod/p...
# 2  Alberto Requena  https://s3.amazonaws.com/garmin-connect-prod/p...
# 3  Alberto Requena  https://s3.amazonaws.com/garmin-connect-prod/p...
# 4  Alberto Requena  https://s3.amazonaws.com/garmin-connect-prod/p...
#
#                           ownerProfileImageUrlMedium  \
# 0  https://s3.amazonaws.com/garmin-connect-prod/p...
# 1  https://s3.amazonaws.com/garmin-connect-prod/p...
# 2  https://s3.amazonaws.com/garmin-connect-prod/p...
# 3  https://s3.amazonaws.com/garmin-connect-prod/p...
# 4  https://s3.amazonaws.com/garmin-connect-prod/p...
#
#                            ownerProfileImageUrlLarge  calories  bmrCalories  \
# 0  https://s3.amazonaws.com/garmin-connect-prod/p...     502.0         51.0
# 1  https://s3.amazonaws.com/garmin-connect-prod/p...     823.0         86.0
# 2  https://s3.amazonaws.com/garmin-connect-prod/p...    1220.0        128.0
# 3  https://s3.amazonaws.com/garmin-connect-prod/p...     652.0         69.0
# 4  https://s3.amazonaws.com/garmin-connect-prod/p...    1176.0        120.0
#
#    averageHR  maxHR  averageRunningCadenceInStepsPerMinute  \
# 0      152.0  174.0                             159.609375
# 1      151.0  176.0                             154.406250
# 2      148.0  164.0                             164.859375
# 3      159.0  192.0                             150.265625
# 4      160.0  176.0                             163.593750
#
#    maxRunningCadenceInStepsPerMinute maxLapAvgRunCadence  \
# 0                              217.0                None
# 1                              194.0                None
# 2                              173.0                None
# 3                              221.0                None
# 4                              172.0                None
#
#   averageBikingCadenceInRevPerMinute maxBikingCadenceInRevPerMinute  \
# 0                               None                           None
# 1                               None                           None
# 2                               None                           None
# 3                               None                           None
# 4                               None                           None
#
#   averageSwimCadenceInStrokesPerMinute maxSwimCadenceInStrokesPerMinute  \
# 0                                 None                             None
# 1                                 None                             None
# 2                                 None                             None
# 3                                 None                             None
# 4                                 None                             None
#
#   averageSwolf activeLengths  steps conversationUuid conversationPk  \
# 0         None          None   5984             None           None
# 1         None          None   9880             None           None
# 2         None          None  15574             None           None
# 3         None          None   7784             None           None
# 4         None          None  14560             None           None
#
#   numberOfActivityLikes numberOfActivityComments likedByUser commentedByUser  \
# 0                  None                     None        None            None
# 1                  None                     None        None            None
# 2                  None                     None        None            None
# 3                  None                     None        None            None
# 4                  None                     None        None            None
#
#   activityLikeDisplayNames activityLikeFullNames activityLikeProfileImageUrls  \
# 0                     None                  None                         None
# 1                     None                  None                         None
# 2                     None                  None                         None
# 3                     None                  None                         None
# 4                     None                  None                         None
#
#   requestorRelationship                                          userRoles  \
# 0                  None  [SCOPE_GOLF_API_READ, SCOPE_ATP_READ, SCOPE_DI...
# 1                  None  [SCOPE_GOLF_API_READ, SCOPE_ATP_READ, SCOPE_DI...
# 2                  None  [SCOPE_GOLF_API_READ, SCOPE_ATP_READ, SCOPE_DI...
# 3                  None  [SCOPE_GOLF_API_READ, SCOPE_ATP_READ, SCOPE_DI...
# 4                  None  [SCOPE_GOLF_API_READ, SCOPE_ATP_READ, SCOPE_DI...
#
#                                privacy  userPro  courseId poolLength  \
# 0  {'typeId': 2, 'typeKey': 'private'}    False       NaN       None
# 1  {'typeId': 2, 'typeKey': 'private'}    False       NaN       None
# 2  {'typeId': 2, 'typeKey': 'private'}    False       NaN       None
# 3  {'typeId': 2, 'typeKey': 'private'}    False       NaN       None
# 4  {'typeId': 2, 'typeKey': 'private'}    False       NaN       None
#
#   unitOfPoolLength  hasVideo videoUrl  timeZoneId  beginTimestamp  \
# 0             None     False     None         124   1716544952000
# 1             None     False     None         124   1716353953000
# 2             None     False     None         124   1716095106000
# 3             None     False     None         124   1715922100000
# 4             None     False     None         124   1715765444000
#
#    sportTypeId avgPower maxPower  aerobicTrainingEffect  \
# 0            1     None     None                    3.5
# 1            1     None     None                    3.9
# 2            1     None     None                    4.4
# 3            1     None     None                    3.7
# 4            1     None     None                    4.6
#
#    anaerobicTrainingEffect strokes normPower leftBalance rightBalance  \
# 0                      0.0    None      None        None         None
# 1                      0.9    None      None        None         None
# 2                      0.0    None      None        None         None
# 3                      1.8    None      None        None         None
# 4                      0.0    None      None        None         None
#
#   avgLeftBalance max20MinPower avgVerticalOscillation avgGroundContactTime  \
# 0           None          None                   None                 None
# 1           None          None                   None                 None
# 2           None          None                   None                 None
# 3           None          None                   None                 None
# 4           None          None                   None                 None
#
#    avgStrideLength avgFractionalCadence maxFractionalCadence  \
# 0       120.844195                 None                 None
# 1       119.233139                 None                 None
# 2       116.833185                 None                 None
# 3       116.602570                 None                 None
# 4       118.445611                 None                 None
#
#   trainingStressScore intensityFactor  vO2MaxValue avgVerticalRatio  \
# 0                None            None         54.0             None
# 1                None            None         54.0             None
# 2                None            None         54.0             None
# 3                None            None          NaN             None
# 4                None            None         54.0             None
#
#   avgGroundContactBalance  lactateThresholdBpm  lactateThresholdSpeed maxFtp  \
# 0                    None                  NaN                    NaN   None
# 1                    None                  NaN                    NaN   None
# 2                    None                  NaN                    NaN   None
# 3                    None                  NaN                    NaN   None
# 4                    None                  NaN                    NaN   None
#
#   avgStrokeDistance avgStrokeCadence maxStrokeCadence    workoutId avgStrokes  \
# 0              None             None             None          NaN       None
# 1              None             None             None  913719347.0       None
# 2              None             None             None          NaN       None
# 3              None             None             None  913719347.0       None
# 4              None             None             None          NaN       None
#
#   minStrokes    deviceId  minTemperature  maxTemperature  minElevation  \
# 0       None  3401978503            24.0            30.0    706.000000
# 1       None  3401978503            18.0            28.0      2.200000
# 2       None  3401978503            10.0            23.0    593.400024
# 3       None  3401978503            14.0            25.0    710.200012
# 4       None  3401978503            18.0            29.0    601.400024
#
#    maxElevation avgDoubleCadence  maxDoubleCadence summarizedExerciseSets  \
# 0    740.200012             None             217.0                   None
# 1     39.000000             None             194.0                   None
# 2    732.799988             None             173.0                   None
# 3    737.000000             None             221.0                   None
# 4    739.200012             None             172.0                   None
#
#   maxDepth avgDepth surfaceInterval startN2 endN2 startCns endCns  \
# 0     None     None            None    None  None     None   None
# 1     None     None            None    None  None     None   None
# 2     None     None            None    None  None     None   None
# 3     None     None            None    None  None     None   None
# 4     None     None            None    None  None     None   None
#
#                                   summarizedDiveInfo activityLikeAuthors  \
# 0  {'weight': None, 'weightUnit': None, 'visibili...                None
# 1  {'weight': None, 'weightUnit': None, 'visibili...                None
# 2  {'weight': None, 'weightUnit': None, 'visibili...                None
# 3  {'weight': None, 'weightUnit': None, 'visibili...                None
# 4  {'weight': None, 'weightUnit': None, 'visibili...                None
#
#   avgVerticalSpeed  maxVerticalSpeed floorsClimbed floorsDescended  \
# 0             None          0.400024          None            None
# 1             None          0.600000          None            None
# 2             None          0.400024          None            None
# 3             None          0.400024          None            None
# 4             None          0.400024          None            None
#
#   manufacturer diveNumber locationName bottomTime  lapCount  endLatitude  \
# 0       GARMIN       None       Madrid       None         8    40.457800
# 1       GARMIN       None    Vila-Seca       None        29    41.106753
# 2       GARMIN       None       Madrid       None        19    40.456842
# 3       GARMIN       None       Madrid       None        30    40.458056
# 4       GARMIN       None       Madrid       None        18    40.446099
#
#    endLongitude minAirSpeed maxAirSpeed avgAirSpeed avgWindYawAngle minCda  \
# 0     -3.694696        None        None        None            None   None
# 1      1.149018        None        None        None            None   None
# 2     -3.693114        None        None        None            None   None
# 3     -3.699058        None        None        None            None   None
# 4     -3.691953        None        None        None            None   None
#
#   maxCda avgCda avgWattsPerCda  flow  grit jumpCount caloriesEstimated  \
# 0   None   None           None  None  None      None              None
# 1   None   None           None  None  None      None              None
# 2   None   None           None  None  None      None              None
# 3   None   None           None  None  None      None              None
# 4   None   None           None  None  None      None              None
#
#   caloriesConsumed  waterEstimated waterConsumed maxAvgPower_1 maxAvgPower_2  \
# 0             None           474.0          None          None          None
# 1             None           683.0          None          None          None
# 2             None           884.0          None          None          None
# 3             None           517.0          None          None          None
# 4             None          1032.0          None          None          None
#
#   maxAvgPower_5 maxAvgPower_10 maxAvgPower_20 maxAvgPower_30 maxAvgPower_60  \
# 0          None           None           None           None           None
# 1          None           None           None           None           None
# 2          None           None           None           None           None
# 3          None           None           None           None           None
# 4          None           None           None           None           None
#
#   maxAvgPower_120 maxAvgPower_300 maxAvgPower_600 maxAvgPower_1200  \
# 0            None            None            None             None
# 1            None            None            None             None
# 2            None            None            None             None
# 3            None            None            None             None
# 4            None            None            None             None
#
#   maxAvgPower_1800 maxAvgPower_3600 maxAvgPower_7200 maxAvgPower_18000  \
# 0             None             None             None              None
# 1             None             None             None              None
# 2             None             None             None              None
# 3             None             None             None              None
# 4             None             None             None              None
#
#   excludeFromPowerCurveReports totalSets activeSets totalReps  \
# 0                         None      None       None      None
# 1                         None      None       None      None
# 2                         None      None       None      None
# 3                         None      None       None      None
# 4                         None      None       None      None
#
#   minRespirationRate maxRespirationRate avgRespirationRate  \
# 0               None               None               None
# 1               None               None               None
# 2               None               None               None
# 3               None               None               None
# 4               None               None               None
#
#   trainingEffectLabel  activityTrainingLoad avgFlow avgGrit  \
# 0               TEMPO            129.103973    None    None
# 1   LACTATE_THRESHOLD            180.751511    None    None
# 2        AEROBIC_BASE            216.560455    None    None
# 3              VO2MAX            174.663025    None    None
# 4   LACTATE_THRESHOLD            236.741470    None    None
#
#    minActivityLapDuration avgStress startStress endStress differenceStress  \
# 0               57.424999      None        None      None             None
# 1               60.000000      None        None      None             None
# 2               89.194000      None        None      None             None
# 3               60.000000      None        None      None             None
# 4               93.647003      None        None      None             None
#
#   maxStress           aerobicTrainingEffectMessage  \
# 0      None                     IMPACTING_TEMPO_22
# 1      None         IMPROVING_LACTATE_THRESHOLD_12
# 2      None  HIGHLY_IMPROVING_AEROBIC_ENDURANCE_10
# 3      None                   IMPROVING_VO2_MAX_15
# 4      None  HIGHLY_IMPROVING_LACTATE_THRESHOLD_13
#
#   anaerobicTrainingEffectMessage  \
# 0         NO_ANAEROBIC_BENEFIT_0
# 1         NO_ANAEROBIC_BENEFIT_0
# 2         NO_ANAEROBIC_BENEFIT_0
# 3     MINOR_ANAEROBIC_BENEFIT_15
# 4         NO_ANAEROBIC_BENEFIT_0
#
#                                       splitSummaries  hasSplits  \
# 0  [{'noOfSplits': 2, 'maxGradeValue': None, 'tot...       True
# 1  [{'noOfSplits': 2, 'maxGradeValue': None, 'tot...       True
# 2  [{'noOfSplits': 1, 'maxGradeValue': None, 'tot...       True
# 3  [{'noOfSplits': 14, 'maxGradeValue': None, 'to...       True
# 4  [{'noOfSplits': 2, 'maxGradeValue': None, 'tot...       True
#
#    moderateIntensityMinutes  vigorousIntensityMinutes maxBottomTime  \
# 0                       0.0                      36.0          None
# 1                       3.0                      60.0          None
# 2                       0.0                      93.0          None
# 3                       2.0                      49.0          None
# 4                       0.0                      88.0          None
#
#   hasSeedFirstbeatProfile calendarEventId calendarEventUuid groupRideUUID  \
# 0                    None            None              None          None
# 1                    None            None              None          None
# 2                    None            None              None          None
# 3                    None            None              None          None
# 4                    None            None              None          None
#
#   avgGradeAdjustedSpeed avgWheelchairCadence maxWheelchairCadence  \
# 0                  None                 None                 None
# 1                  None                 None                 None
# 2                  None                 None                 None
# 3                  None                 None                 None
# 4                  None                 None                 None
#
#   avgJumpRopeCadence maxJumpRopeCadence gameName differenceBodyBattery  \
# 0               None               None     None                  None
# 1               None               None     None                  None
# 2               None               None     None                  None
# 3               None               None     None                  None
# 4               None               None     None                  None
#
#   gameType curatedCourseId matchedCuratedCourseId  parent  favorite  decoDive  \
# 0     None            None                   None   False     False     False
# 1     None            None                   None   False     False     False
# 2     None            None                   None   False     False     False
# 3     None            None                   None   False     False     False
# 4     None            None                   None   False     False     False
#
#    purposeful     pr  manualActivity  autoCalcCalories  elevationCorrected  \
# 0       False  False           False             False               False
# 1       False  False           False             False               False
# 2       False  False           False             False               False
# 3       False  False           False             False               False
# 4       False  False           False             False               False
#
#    atpActivity
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# Keep only relevant columns
df_g = df_g[['activityId',
            'activityName',
            'startTimeLocal',
            'distance',
           # 'movingDuration',
            'elevationGain',
           # 'elevationLoss',
            'averageSpeed',
            'maxSpeed',
            'calories',
            'averageHR'
           # 'maxHR',
           # 'maxElevation',
           # 'activityTrainingLoad']]
]]
# Add date column as date
df_g['date'] = pd.to_datetime(df_g['startTimeLocal']).dt.date
df_g = df_g[['date'] + [col for col in df_g.columns if col != 'date']]

# Merge the two dataframes
df = pd.merge(df_g, df_t, on='date', how='inner')
df.head()
# Out:
#          date   activityId              activityName       startTimeLocal  \
# 0  2024-05-19  15464994914            Madrid Carrera  2024-05-19 07:05:06
# 1  2024-05-17  15433085610           Madrid - 12x300  2024-05-17 07:01:40
# 2  2024-05-15  15403874461            Madrid Carrera  2024-05-15 11:30:44
# 3  2024-05-12  15360575155            Madrid Carrera  2024-05-12 19:09:09
# 4  2024-05-11  15342915004  Guadarrama Trail running  2024-05-11 17:31:36
#
#        distance  elevationGain  averageSpeed  maxSpeed  calories  averageHR  \
# 0  18280.839844         179.52         3.212     4.161    1220.0      148.0
# 1   9279.959961          41.89         3.009     4.665     652.0      159.0
# 2  17284.039062         164.94         3.232     3.863    1176.0      160.0
# 3   3679.590088          17.46         3.435     3.928     229.0      142.0
# 4   8943.410156         256.34         3.286     5.039     653.0      168.0
#
#       TSS
# 0  139.90
# 1   64.28
# 2  131.88
# 3   82.69
# 4   78.11

# %%
### Get the raw TP data and see which days have more than one training, eliminate those
# Load workout data from CSV
df_tr = pd.read_csv('Data/TrainingPeaks/workouts.csv', parse_dates=['WorkoutDay'])

# Get number of workouts per day
df_tr.rename(columns={'WorkoutDay': 'date'}, inplace=True)
df_tr['count'] = df_tr.groupby('date')['date'].transform('count')
df_tr = df_tr[['date', 'count']]
df_tr['date'] = pd.to_datetime(df_tr['date']).dt.date

# Merge the two dataframes
df = pd.merge(df, df_tr, on='date', how='left')
# Delete rows with more than one workout
df = df[df['count'] == 1]
df.drop(columns=['count'], inplace=True)

# %%
import pandas as pd
import statsmodels.api as sm

# Assuming the dataset is already loaded into a DataFrame named df
data = df.copy()

# Drop columns that are not needed for the model
data = data.drop(columns=['activityId', 'activityName', 'startTimeLocal', 'date'])

# Convert all columns to numeric, coerce errors to handle non-numeric values
data = data.apply(pd.to_numeric, errors='coerce')

# Drop rows with missing values
data = data.dropna()
data.head()
# Out:
#        distance  elevationGain  averageSpeed  maxSpeed  calories  averageHR  \
# 0  18280.839844         179.52         3.212     4.161    1220.0      148.0
# 1   9279.959961          41.89         3.009     4.665     652.0      159.0
# 2  17284.039062         164.94         3.232     3.863    1176.0      160.0
# 5   8943.410156         256.34         3.286     5.039     653.0      168.0
# 6  11570.459961          40.29         3.092     4.647     827.0      160.0
#
#       TSS
# 0  139.90
# 1   64.28
# 2  131.88
# 5   78.11
# 6   82.38

# %%
# Define features and target variable
X = data.drop(columns=['TSS'])  # Features
y = data['TSS']  # Target variable (TSS)

# Split the data into training and testing sets
train_size = int(0.8 * len(data))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Create and train the regression model
model = sm.OLS(y_train, X_train).fit()

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = ((y_test - y_pred) ** 2).mean()
r2 = model.rsquared

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Summary of the model
print(model.summary())
# Out:
# Mean Squared Error: 17.08857408606121
# R^2 Score: 0.9964112201339146
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    TSS   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                              4165.
# Date:                Sat, 25 May 2024   Prob (F-statistic):                   1.01e-107
# Time:                        09:50:15   Log-Likelihood:                         -292.56
# No. Observations:                  96   AIC:                                      597.1
# Df Residuals:                      90   BIC:                                      612.5
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# distance          0.0039      0.002      2.561      0.012       0.001       0.007
# elevationGain     0.0131      0.011      1.149      0.253      -0.010       0.036
# averageSpeed     22.4105      3.465      6.468      0.000      15.527      29.294
# maxSpeed         -1.3294      0.646     -2.059      0.042      -2.612      -0.047
# calories          0.0472      0.023      2.090      0.039       0.002       0.092
# averageHR        -0.4057      0.069     -5.863      0.000      -0.543      -0.268
# ==============================================================================
# Omnibus:                       36.625   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.300
# Skew:                           1.351   Prob(JB):                     3.34e-21
# Kurtosis:                       7.034   Cond. No.                     7.57e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 7.57e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import matplotlib.pyplot as plt
import shap

# Create a SHAP explainer for the linear regression model
explainer = shap.Explainer(model.predict, X)
shap_values = explainer(X)

# Plot SHAP values
shap.summary_plot(shap_values, X)

# Plot SHAP values for individual feature
shap.plots.bar(shap_values)

# Calculate and plot variable importance
importances = pd.DataFrame({'Feature': X.columns, 'Importance': model.params})
importances = importances.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(importances['Feature'], importances['Importance'])
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.title('Variable Importance')
plt.gca().invert_yaxis()
plt.show()

# %%
# Make predictions on the dataset
df['Predicted_TSS'] = model.predict(X)

# Plot predicted vs real values as xy chart
plt.figure(figsize=(10, 6))
plt.scatter(df['TSS'], df['Predicted_TSS'])
plt.plot([0, 200], [0, 200], color='red', linestyle='--')
plt.xlabel('Actual TSS')
plt.ylabel('Predicted TSS')
plt.title('Actual vs Predicted TSS')
plt.show()

# Calculate the absolute difference between actual and predicted TSS
df['Absolute_Error'] = abs(df['TSS'] - df['Predicted_TSS'])

# Create a new dataset with cases where the absolute error is greater than 10 percent
off_by_more_than_10 = df[df['Absolute_Error'] > 0.1 * df['TSS']]

# Drop the 'Absolute_Error' column if no longer needed
off_by_more_than_10 = off_by_more_than_10.drop(columns=['Absolute_Error'])

off_by_more_than_10
# Out:
#            date   activityId              activityName       startTimeLocal  \
# 5    2024-05-11  15342915004  Guadarrama Trail running  2024-05-11 17:31:36
# 17   2024-04-21  15001860838      Madrid Trail running  2024-04-21 08:58:10
# 25   2024-04-07  14774594162            Madrid Carrera  2024-04-07 09:18:16
# 71   2024-01-07  13396372172            Madrid Carrera  2024-01-07 10:22:04
# 81   2023-12-03  12962163156            Madrid Carrera  2023-12-03 08:30:18
# 85   2023-11-21  12814404607            Madrid Carrera  2023-11-21 07:34:57
# 90   2023-11-09  12661747255        Madrid - 5x10min,2  2023-11-09 08:35:36
# 94   2023-11-01  12553342624    Madrid - 10x5min, 2min  2023-11-01 09:44:07
# 97   2023-10-24  12444190964            Madrid Carrera  2023-10-24 07:13:47
# 110  2023-08-01  11692495489            Madrid Carrera  2023-08-01 19:25:58
# 111  2023-07-30  11674041962            Madrid Carrera  2023-07-30 11:21:42
# 115  2023-07-22  11615671550            Madrid Carrera  2023-07-22 10:33:29
#
#          distance  elevationGain  averageSpeed  maxSpeed  calories  averageHR  \
# 5     8943.410156         256.34         3.286     5.039     653.0      168.0
# 17   14196.679688         222.08         2.604     3.751     986.0      137.0
# 25   21315.210938         151.70         3.575     4.357    1472.0      174.0
# 71    9356.860352          41.58         2.579     3.966     648.0      146.0
# 81    6727.450195          31.82         2.017     4.283     460.0      125.0
# 85    6872.709961          51.21         2.093     4.572     536.0      144.0
# 90    9815.280273          39.05         2.718     3.312     696.0      150.0
# 94   10722.879883          24.72         2.428     3.303     775.0      149.0
# 97    5045.009766          52.33         2.802     3.760     394.0      168.0
# 110  12593.019531          91.58         2.551     4.236     901.0      143.0
# 111   7716.509766          81.49         2.400     4.497     645.0      150.0
# 115   7806.600098          84.10         2.570     3.639     655.0      155.0
#
#         TSS  Predicted_TSS
# 5     78.11      68.187103
# 17    92.69     103.154967
# 25   177.12     159.156747
# 71    55.51      61.275248
# 81    31.42      37.420131
# 85    57.44      35.446222
# 90    61.34      67.675793
# 94    60.16      68.711605
# 97    33.74      28.788827
# 110   78.71      86.851503
# 111   62.70      48.858884
# 115   68.44      52.641811

# %%
# Print % of activities with Prediction Error > 10%
print(f'Activities with Prediction Error > 10%: {len(off_by_more_than_10) / len(df) * 100:.2f}%')
# Out:
# Activities with Prediction Error > 10%: 9.76%
